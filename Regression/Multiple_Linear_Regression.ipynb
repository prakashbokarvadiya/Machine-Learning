# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"E:\tops\Data science\practical\Regression\multiple_regression_sample.csv")
dataset.head(3)
# Out:
#    age  experience    salary
# 0   50          23  97965.35
# 1   36          10  72702.37
# 2   29           8  47393.66

# %%
dataset.isnull().sum()
# Out:
# age           0
# experience    0
# salary        0
# dtype: int64

# %%
dataset.shape
# Out:
# (200, 3)

# %%
plt.figure(figsize=(10,6))
plt.subplot
sns.pairplot(dataset)
#sns.scatterplot(x="age",y="income",data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["salary"]

# %%
x.ndim
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=13)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9780602500309589

# %%
lr.coef_
# Out:
# array([1059.86173425, 1185.5127257 ])

# %%
lr.intercept_
# Out:
# np.float64(22979.81687461736)

# %%
x_test.shape
# Out:
# (40, 2)

# %%
x_test.head(-5)
# Out:
#      age  experience
# 179   55          35
# 155   23           0
# 23    48          26
# 159   23           0
# 96    56          28
# 198   28           5
# 42    29           1
# 110   30          10
# 128   49          29
# 97    43          14
# 95    58          37
# 106   26           5
# 65    39          14
# 33    25           5
# 102   58          31
# 89    29           9
# 132   49          28
# 79    32          12
# 104   24           0
# 70    36          15
# 173   25           0
# 129   23           0
# 30    42          22
# 7     32          11
# 168   23           0
# 124   34           8
# 157   58          36
# 165   54          27
# 101   56          29
# 78    45          25
# 87    28           4
# 141   34           5
# 105   22           0
# 10    45          23
# 64    37          12

# %%
import numpy as np
lr.predict(x_test)
# Out:
# array([122765.15765767,  47356.63676232, 104676.51098666,  47356.63676232,
#        115526.43031203,  58583.50906204,  54901.3198935 ,  66630.79615903,
#        109292.910898  ,  85151.04960704, 128315.76831181,  56463.78559355,
#         80911.60267005,  55403.9238593 , 121202.69195762,  64385.42169908,
#        108107.3981723 ,  71121.54507892,  48416.49849656,  78917.53019301,
#         49476.36023081,  47356.63676232,  93575.28967838,  69936.03235322,
#         47356.63676232,  68499.21764463, 127130.25558611, 112221.19411784,
#        116711.94303773, 100311.41305821,  57397.99633635,  64942.67946753,
#         46296.77502807,  97940.38760682,  76420.85375016,  47356.63676232,
#         69810.38136177, 113783.65981789,  79600.4389529 ,  97940.38760682])

# %%
dataset.head(24)
# Out:
#     age  experience     salary
# 0    50          23   97965.35
# 1    36          10   72702.37
# 2    29           8   47393.66
# 3    42          15   79878.06
# 4    40          20   87737.16
# 5    44          16   81961.08
# 6    32           4   69962.06
# 7    32          11   63049.29
# 8    45          19   90599.78
# 9    57          28  116253.70
# 10   45          23  104806.37
# 11   24           0   41820.69
# 12   43          14   90615.82
# 13   23           0   48051.17
# 14   45          22   91492.46
# 15   51          31  115510.52
# 16   59          38  130595.30
# 17   23           3   48598.92
# 18   42          18   88949.01
# 19   54          30  113073.43
# 20   33           7   66967.59
# 21   43          15   89310.65
# 22   46          18  100530.08
# 23   48          26   98010.92
