# %%
import pandas as pd 

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
dataset =pd.read_csv(r"E:\tops\Data science\practical\placement (1).csv")
dataset.head(10)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# 5  7.89     2.99
# 6  6.73     2.60
# 7  6.75     2.48
# 8  6.09     2.31
# 9  8.31     3.51

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x="cgpa",y="package",data=dataset)
plt.show()

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x = dataset[["cgpa"]]
y = dataset["package"]
x.ndim,y.ndim
# Out:
# (2, 1)

# %%
plt.subplot(1,2,1)
plt.title("cgpa")
sns.distplot(x)
plt.subplot(1,2,2)
plt.title("package")
sns.distplot(y)
plt.show()
# Out:
# C:\Users\thako\AppData\Local\Temp\ipykernel_19544\2843610058.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# C:\Users\thako\AppData\Local\Temp\ipykernel_19544\2843610058.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=41)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
6.89 	3.26

# %%
lr.score(x_test,y_test)*100
# Out:
# 79.12038963503235

# %%
y_prd=lr.predict([[6.89]])
# Out:
# E:\app\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_prd=lr.predict(x)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot( x="cgpa",y="package",data=dataset)
plt.plot(dataset["cgpa"],y_prd,c="red")
plt.legend(["org data","predict line"])
plt.show()
